# %% [markdown]
# ### Diskuter hvordan man induserer flow i et nano-porøst materiale:
# Vi induserer en strømning i et nanoporøst materiale ved å introdusere en ekstrern kraft som virker på hver partikkel i fluidet. For en strømning i et gravitasjonsfelt har vi fra Darcy's lov $U = \frac{k}{\mu}(\nabla P - \rho g)$, hvor $\rho$ er massetettheten til fluidet og $g$ er tyngdeaksellerasjonen.
#
# Vi kan erstatte $\rho g$ med den eksterne kraften som virker på hver partikkel:
# \begin{equation}
#     \rho g = \frac{M}{V}g = \frac{N}{V}mg = \frac{N}{V}G = \frac{N}{V}F_x = nF_x.
# \end{equation}
#
# Dette gir at strømningsprofilen blir $U = \frac{k}{\mu}(\nabla P - nF_x)$

# %% [markdown]
# ### Hvordan kan du sjekke modellen:
# Vi vet at for en sylindrisk pore i et ellers fast materiale forventer vi at en strøm har en parabolisk form tilsvarende:
#
# \begin{equation}
# u(r) = \frac{G}{4\mu}(a^2 - r^2) = \frac{F_x}{4\mu}(a^2 - r^2)
# \end{equation}
#
# hvor vi har satt inn $G = F_x$.
#
# Vi ser på et system som er $20x20x20$ enhetsceller, systemet tempereres til $T = 1.5$ og lager en sylindrisk pore med radius 2 nm.
#
# ![vel_profile.png](attachment:vel_profile.png)
#
# Her kan vi se flow profilen til systemet vårt og vi ser at dette gir en parabolisk strømningsprofil, slik som forventet.

# %% [markdown]
# For å regne ut viskøsiteten løser vi
#
# \begin{equation}
# u(r) = \frac{F_x}{4\mu}(a^2 - r^2)
# \end{equation}
#
# for $\mu$:
#
# \begin{equation}
# \mu = \frac{F_x}{4u(r)}(a^2 - r^2).
# \end{equation}
#
# For systemet vårt fant vi at viskøsiteten $\mu \approx 0.38$.

# %% [markdown]
# For å finne viskositeten til et fluid kan vi bruke Darcy's lov
#
# \begin{equation}
# \langle u \rangle = \frac{G}{8\mu}a^2 =\frac{Q}{\pi a^2} = \frac{a^2}{8\mu}\frac{\Delta p}{L},
# \end{equation}
#
# Vi vet også at Darcy hastigheten er gitt ved
#
# \begin{equation}
# \langle u \rangle = \frac{U}{\phi}
# \end{equation}
#
# Sammen gir dette
#
# \begin{equation}
# U = \phi \frac{a^2}{8\mu}\frac{\Delta p}{L} = \frac{k}{\mu}\frac{\Delta p}{L}
# \end{equation}
#
# For en inkompressibel væske er $\Delta p = p_2 - p_1 = \rho g L$, insatt gir dette
#
# \begin{equation}
# U =
# \end{equation}

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-1, 1, 1000)
r = 1
G = 1
mu = 1

plt.plot(x, r*r - x*x)
plt.title(f'Flow profile')
plt.legend(['$v(x)$'])
plt.xlabel('x')
plt.ylabel('$r^2 - x^2$')
plt.show()
